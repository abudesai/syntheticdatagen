# %%
## Necessary packages
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np
import warnings
warnings.filterwarnings("ignore")

# 1. TimeGAN model
from timegan import timegan
# 2. Data loading
from data_loading import real_data_loading, sine_data_generation
# 3. Metrics
from metrics.discriminative_metrics import discriminative_score_metrics
from metrics.predictive_metrics import predictive_score_metrics
from metrics.visualization_metrics import visualization

import tensorflow as tf

import os

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "2"
config = tf.compat.v1.ConfigProto() # Another Version: config = tf.ConfigProto()
config.gpu_options.allow_growth = True

# %%
## Data loading
data_name = 'sine'
seq_len = 24

if data_name in ['stock', 'energy']:
  ori_data = real_data_loading(data_name, seq_len)
elif data_name == 'sine':
  # Set number of samples and its dimensions
  no, dim = 10000, 5
  ori_data = sine_data_generation(no, seq_len, dim)
    
print(data_name + ' dataset is ready.')
# Out:
# sine dataset is ready.

# %%
# Run TimeGAN
generated_data = np.load("sine_data_TimeGAN_5000_sce2-1.npy")   
print('Finish Synthetic Data Generation')
# Out:
# Finish Synthetic Data Generation

# %%
generated_data.shape, np.asarray(ori_data).shape
# Out:
# ((392000, 24, 5), (10000, 24, 5))

# %%
generated_data[0][0]
# Out:
# array([0.5196928 , 0.52700622, 0.52452335, 0.51944418, 0.52171952])

# %%
metric_iteration = 5

predictive_score = list()
for tt in range(metric_iteration):
  temp_pred = predictive_score_metrics(ori_data, generated_data)
  predictive_score.append(temp_pred)   
    
print("the predictive scores are:", predictive_score)
print("the average value of predicted score: ", str(np.round(np.mean(predictive_score), 4)))
print("the std value of predicted score: ", str(np.round(np.std(predictive_score), 4)))
# Out:
# WARNING:tensorflow:From /data/home/stufs1/zuwang/dg21/TimeGAN/metrics/predictive_metrics.py:37: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /data/home/stufs1/zuwang/dg21/TimeGAN/metrics/predictive_metrics.py:56: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /data/home/stufs1/zuwang/dg21/TimeGAN/metrics/predictive_metrics.py:72: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /data/home/stufs1/zuwang/dg21/TimeGAN/metrics/predictive_metrics.py:72: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From /data/home/stufs1/zuwang/dg21/TimeGAN/metrics/predictive_metrics.py:73: GRUCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.GRUCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /data/home/stufs1/zuwang/dg21/TimeGAN/metrics/predictive_metrics.py:74: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /home/stufs1/zuwang/anaconda3/envs/dg21/lib/python3.7/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:559: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /home/stufs1/zuwang/anaconda3/envs/dg21/lib/python3.7/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:565: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/stufs1/zuwang/anaconda3/envs/dg21/lib/python3.7/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:575: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/stufs1/zuwang/anaconda3/envs/dg21/lib/python3.7/site-packages/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /home/stufs1/zuwang/anaconda3/envs/dg21/lib/python3.7/site-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1866: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /data/home/stufs1/zuwang/dg21/TimeGAN/metrics/predictive_metrics.py:77: all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Please use tf.global_variables instead.
# WARNING:tensorflow:From /data/home/stufs1/zuwang/dg21/TimeGAN/metrics/predictive_metrics.py:83: The name tf.losses.absolute_difference is deprecated. Please use tf.compat.v1.losses.absolute_difference instead.
#
# WARNING:tensorflow:From /data/home/stufs1/zuwang/dg21/TimeGAN/metrics/predictive_metrics.py:85: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /data/home/stufs1/zuwang/dg21/TimeGAN/metrics/predictive_metrics.py:89: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# 2021-08-12 12:42:49.541929: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-08-12 12:42:49.591282: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla V100-PCIE-32GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 0000:af:00.0
# 2021-08-12 12:42:49.591536: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-08-12 12:42:49.593000: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2021-08-12 12:42:49.594786: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2021-08-12 12:42:49.595082: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2021-08-12 12:42:49.596560: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2021-08-12 12:42:49.597910: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2021-08-12 12:42:49.603231: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-08-12 12:42:49.606645: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2021-08-12 12:42:49.607950: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# 2021-08-12 12:42:49.627777: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2800000000 Hz
# 2021-08-12 12:42:49.634651: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x558f8f046bd0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-08-12 12:42:49.634722: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-08-12 12:42:49.637896: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla V100-PCIE-32GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 0000:af:00.0
# 2021-08-12 12:42:49.638124: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-08-12 12:42:49.638153: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2021-08-12 12:42:49.638177: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2021-08-12 12:42:49.638198: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2021-08-12 12:42:49.638220: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2021-08-12 12:42:49.638242: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2021-08-12 12:42:49.638264: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-08-12 12:42:49.643557: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2021-08-12 12:42:49.643660: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# WARNING:tensorflow:From /data/home/stufs1/zuwang/dg21/TimeGAN/metrics/predictive_metrics.py:90: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
# 2021-08-12 12:42:49.817540: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-08-12 12:42:49.817571: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2021-08-12 12:42:49.817576: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2021-08-12 12:42:49.823983: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30591 MB memory) -> physical GPU (device: 0, name: Tesla V100-PCIE-32GB, pci bus id: 0000:af:00.0, compute capability: 7.0)
# 2021-08-12 12:42:49.831020: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x558f93cd8750 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-08-12 12:42:49.831233: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-PCIE-32GB, Compute Capability 7.0
# 2021-08-12 12:42:51.126330: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2021-08-12 12:46:33.089911: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla V100-PCIE-32GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 0000:af:00.0
# 2021-08-12 12:46:33.090044: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-08-12 12:46:33.090075: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2021-08-12 12:46:33.090111: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2021-08-12 12:46:33.090137: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2021-08-12 12:46:33.090167: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2021-08-12 12:46:33.090194: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2021-08-12 12:46:33.090222: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-08-12 12:46:33.091233: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2021-08-12 12:46:33.091307: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-08-12 12:46:33.091311: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2021-08-12 12:46:33.091315: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2021-08-12 12:46:33.092606: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30591 MB memory) -> physical GPU (device: 0, name: Tesla V100-PCIE-32GB, pci bus id: 0000:af:00.0, compute capability: 7.0)
# 2021-08-12 12:50:08.431870: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla V100-PCIE-32GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 0000:af:00.0
# 2021-08-12 12:50:08.432004: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-08-12 12:50:08.432019: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2021-08-12 12:50:08.432033: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2021-08-12 12:50:08.432045: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2021-08-12 12:50:08.432057: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2021-08-12 12:50:08.432070: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2021-08-12 12:50:08.432082: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-08-12 12:50:08.433115: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2021-08-12 12:50:08.433155: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-08-12 12:50:08.433160: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2021-08-12 12:50:08.433163: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2021-08-12 12:50:08.434220: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30591 MB memory) -> physical GPU (device: 0, name: Tesla V100-PCIE-32GB, pci bus id: 0000:af:00.0, compute capability: 7.0)
# 2021-08-12 12:53:44.769568: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla V100-PCIE-32GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 0000:af:00.0
# 2021-08-12 12:53:44.769744: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-08-12 12:53:44.769773: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2021-08-12 12:53:44.769798: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2021-08-12 12:53:44.769821: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2021-08-12 12:53:44.769842: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2021-08-12 12:53:44.769864: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2021-08-12 12:53:44.769886: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-08-12 12:53:44.771117: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2021-08-12 12:53:44.771185: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-08-12 12:53:44.771192: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2021-08-12 12:53:44.771197: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2021-08-12 12:53:44.772587: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30591 MB memory) -> physical GPU (device: 0, name: Tesla V100-PCIE-32GB, pci bus id: 0000:af:00.0, compute capability: 7.0)
# 2021-08-12 12:57:22.446759: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla V100-PCIE-32GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 0000:af:00.0
# 2021-08-12 12:57:22.446882: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-08-12 12:57:22.446901: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2021-08-12 12:57:22.446920: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2021-08-12 12:57:22.446935: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2021-08-12 12:57:22.446951: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2021-08-12 12:57:22.446966: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2021-08-12 12:57:22.446982: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-08-12 12:57:22.448028: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2021-08-12 12:57:22.448070: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-08-12 12:57:22.448074: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2021-08-12 12:57:22.448078: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2021-08-12 12:57:22.449600: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30591 MB memory) -> physical GPU (device: 0, name: Tesla V100-PCIE-32GB, pci bus id: 0000:af:00.0, compute capability: 7.0)
# Predictive score: 0.1237

# %%
visualization(ori_data, generated_data, 'pca')
visualization(ori_data, generated_data, 'tsne')
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 2000 samples in 0.000s...
# [t-SNE] Computed neighbors for 2000 samples in 0.112s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2000
# [t-SNE] Computed conditional probabilities for sample 2000 / 2000
# [t-SNE] Mean sigma: 0.024848
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 58.706306
# [t-SNE] KL divergence after 300 iterations: 0.792958

# %%
# Out:
# (10024, 5)
