# %%
import numpy as np, pandas as pd
import os, sys
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import statsmodels.api as sm

# %%
import statsmodels
data_dir = 'data'

# %%
data_dict = {
    'energy': {
        'file': 'Energy-energydata_complete.csv',
        'time_col': 'date',
        'time_steps_per_day': 1, 
        'has_weekends': False,
        'max_lags': 250,
    },
    'stocks': {
        'file': 'Stock-GOOG.csv',
        'time_col': 'Date', 
        'time_steps_per_day': 24*6, 
        'has_weekends': True,
        'max_lags': 4320,       
    }
}

# %% [markdown]
# ## Choose Data

# %%
selected = 'energy'
selected = 'stocks'

# %%
file_path = os.path.join(data_dir, data_dict[selected]['file'])
data = pd.read_csv(file_path, parse_dates=[data_dict[selected]['time_col']])
print(data.head())
# Out:
#                  date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0 2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1 2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2 2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3 2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4 2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
#    RH_out  Windspeed  Visibility  Tdewpoint        rv1        rv2
# 0    92.0   7.000000   63.000000        5.3  13.275433  13.275433
# 1    92.0   6.666667   59.166667        5.2  18.606195  18.606195
# 2    92.0   6.333333   55.333333        5.1  28.642668  28.642668
# 3    92.0   6.000000   51.500000        5.0  45.410389  45.410389
# 4    92.0   5.666667   47.666667        4.9  10.084097  10.084097
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Extract date feature

# %%
time_col = data_dict[selected]['time_col']

# %%
data[time_col] = data[time_col].apply(lambda t: t.date())
data.head()
# Out:
#          date  Appliances  lights     T1       RH_1    T2       RH_2     T3  \
# 0  2016-01-11          60      30  19.89  47.596667  19.2  44.790000  19.79
# 1  2016-01-11          60      30  19.89  46.693333  19.2  44.722500  19.79
# 2  2016-01-11          50      30  19.89  46.300000  19.2  44.626667  19.79
# 3  2016-01-11          50      40  19.89  46.066667  19.2  44.590000  19.79
# 4  2016-01-11          60      40  19.89  46.333333  19.2  44.530000  19.79
#
#         RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  RH_out  \
# 0  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5    92.0
# 1  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6    92.0
# 2  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7    92.0
# 3  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8    92.0
# 4  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9    92.0
#
#    Windspeed  Visibility  Tdewpoint        rv1        rv2
# 0   7.000000   63.000000        5.3  13.275433  13.275433
# 1   6.666667   59.166667        5.2  18.606195  18.606195
# 2   6.333333   55.333333        5.1  28.642668  28.642668
# 3   6.000000   51.500000        5.0  45.410389  45.410389
# 4   5.666667   47.666667        4.9  10.084097  10.084097
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Group data by time col

# %%
groupby_col = time_col
val_cols = list(data.columns)
val_cols = [c for c in val_cols if c != groupby_col]
grouped_data = data.groupby(groupby_col, as_index=False)[val_cols].sum()
grouped_data.sort_values(by=groupby_col, inplace=True)
del grouped_data[groupby_col]
grouped_data.reset_index(drop=True, inplace=True)
grouped_data.head()
# Out:
#    Appliances  lights           T1         RH_1           T2         RH_2  \
# 0        5740    1260   873.960000  1970.060833   846.440000  1881.313333
# 1       12340     610  2893.295000  6500.450000  2780.302252  6304.281622
# 2       13970     780  2764.486667  6172.959167  2673.865809  6065.232351
# 3       21800     720  2933.579167  6110.667500  2843.010833  5860.680833
# 4       18050     860  3208.456667  5630.298333  3100.056764  5499.921234
#
#             T3         RH_3           T4         RH_4  ...           T9  \
# 0   845.920833  1931.682500   818.673333  1984.954167  ...   710.563333
# 1  2879.085000  6470.376667  2847.280000  6416.185000  ...  2452.730000
# 2  2823.726667  6295.808333  2737.411667  6093.385000  ...  2441.315000
# 3  3000.611667  6249.562500  2691.975000  6225.271667  ...  2431.413333
# 4  3018.106667  5963.023333  2824.578333  6042.389167  ...  2497.780000
#
#           RH_9   T_out  Press_mm_hg   RH_out  Windspeed  Visibility  \
# 0  1894.460833  248.75     30877.30   3750.0      255.5      1715.5
# 1  6577.938333  801.55    106938.45  12600.0      833.0      5361.0
# 2  6435.572500  699.40    108689.85  12010.5      808.5      4544.5
# 3  6541.665000  494.20    107966.50  12444.5      904.0      5061.5
# 4  6412.943333  383.80    108659.50  12727.5     1119.0      5790.0
#
#    Tdewpoint          rv1          rv2
# 0     177.60  1102.449602  1102.449602
# 1     517.90  3672.730349  3672.730349
# 2     312.45  3378.920507  3378.920507
# 3     189.60  3638.097980  3638.097980
# 4     122.35  3785.690222  3785.690222
#
# [5 rows x 28 columns]

# %%
# save num_dim
N, D = grouped_data.shape
N, D
# Out:
# (138, 28)

# %% [markdown]
# ## Train Test Split

# %%
train_perc = 0.8
test_perc = 1 - train_perc

N = grouped_data.shape[0]
num_train = int(N * train_perc)
num_test = N - num_train
print(N, num_train, num_test)
# Out:
# 138 110 28

# %%
train_data = grouped_data.head(num_train).copy()
test_data = grouped_data.tail(num_test).copy()
print('train/test shapes:', train_data.shape, test_data.shape)
# Out:
# train/test shapes: (110, 28) (28, 28)

# %% [markdown]
# ### Min Max Scale

# %%
scaler = MinMaxScaler()
train_data_arr = scaler.fit_transform(train_data)
test_data_arr = scaler.transform(test_data)

train_data = pd.DataFrame(train_data_arr, columns = train_data.columns, index=train_data.index)
test_data = pd.DataFrame(test_data_arr, columns = test_data.columns, index=test_data.index)

print('train/test shapes:', train_data_arr.shape, test_data_arr.shape)
# Out:
# train/test shapes: (110, 28) (28, 28)

# %%
print(train_data.min(axis=0), train_data.max(axis=0))
# Out:
# Appliances     0.0
# lights         0.0
# T1             0.0
# RH_1           0.0
# T2             0.0
# RH_8         0.317488     0.496687  0.653017   0.478240    0.267447
# T9           0.459273     0.654687  0.113784   0.003823    0.165723
# RH_9         0.384937     0.581452  0.593331   0.475020    0.281711
# T_out        1.000000     0.093960 -0.170351   0.386324   -0.127366
# Press_mm_hg  0.093960     1.000000  0.555528   0.074263    0.480075
# RH_out      -0.170351     0.555528  1.000000   0.051694    0.413019
# Windspeed    0.386324     0.074263  0.051694   1.000000   -0.030043
# Visibility  -0.127366     0.480075  0.413019  -0.030043    1.000000
# Tdewpoint    0.900915     0.013954  0.144710   0.398062   -0.087776
# rv1          0.016835     0.791346  0.513561  -0.030075    0.381573
# rv2          0.016835     0.791346  0.513561  -0.030075    0.381573
#
#              Tdewpoint       rv1       rv2
# Appliances    0.051932  0.115118  0.115118
# lights        0.025843 -0.096774 -0.096774
# T1            0.276290  0.645913  0.645913
# RH_1          0.551182  0.440988  0.440988
# T2            0.374747  0.594888  0.594888
# RH_2          0.567399  0.505058  0.505058
# T3            0.374001  0.574880  0.574880
# RH_3          0.373941  0.451246  0.451246
# T4            0.202762  0.572647  0.572647
# RH_4          0.572226  0.350929  0.350929
# T5            0.319662  0.571800  0.571800
# RH_5          0.127940  0.395366  0.395366
# T6            0.889661  0.015336  0.015336
# RH_6         -0.095378  0.119629  0.119629
# T7            0.131208  0.556570  0.556570
# RH_7          0.588893  0.292311  0.292311
# T8            0.136909  0.571586  0.571586
# RH_8          0.487575  0.362486  0.362486
# T9            0.270813  0.546656  0.546656
# RH_9          0.497128  0.417640  0.417640
# T_out         0.900915  0.016835  0.016835
# Press_mm_hg   0.013954  0.791346  0.791346
# RH_out        0.144710  0.513561  0.513561
# Windspeed     0.398062 -0.030075 -0.030075
# Visibility   -0.087776  0.381573  0.381573
# Tdewpoint     1.000000 -0.012823 -0.012823
# rv1          -0.012823  1.000000  1.000000
# rv2          -0.012823  1.000000  1.000000
#
# [28 rows x 28 columns]

# %%
mean_corr = corr.mean().mean()
mean_corr
# Out:
# 0.4070318915531758

# %% [markdown]
# # Auto Correlation

# %% [markdown]
# ### PACF Plot

# %%
lags = min(data_dict[selected]['max_lags'], np.floor(train_data.shape[0] * 0.5) - 1)
print('lags:', lags)

max_plots_to_draw = 50
num_plots = min(len(val_cols), max_plots_to_draw)

figsize = (12, 2 + 3*num_plots)
fig, axs = plt.subplots(len(val_cols[: num_plots]), 1, figsize=figsize)

for i, col in enumerate(val_cols[:num_plots]):
    sm.graphics.tsa.plot_pacf(train_data[col].values.squeeze(), lags=lags, ax = axs[i])
    axs[i].set_title(col)
    
plt.subplots_adjust(top = 0.90, bottom=0.1, hspace=.4, wspace=0.4)
# Out:
# lags: 54.0
# C:\Users\abhyuday.desai\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1434: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)
# C:\Users\abhyuday.desai\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1434: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)
# C:\Users\abhyuday.desai\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1434: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)
