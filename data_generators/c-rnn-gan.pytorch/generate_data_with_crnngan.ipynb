# %%
import numpy as np, pandas as pd
import time

# %%
model = 'crnngan'

dataset_names = ['sine', 'stocks', 'air', 'energy']
percs = [2, 5, 10, 20, 100]


# crnngan specific variables - dont change these
given_seq_len = 24       # length of sequences


# to custom run specific data
dataset_names = ['stocks']
percs = [ 2 ]


start = time.time()

for data_name in dataset_names:    
    for p in percs: 
        
        print("="*80)
        print(f"Running data: {data_name}, perc: {p}")        
        
        
        # !python train_data_gen_updated.py \
                --dataset $data_name \
                --training_thresh $p \
                --valid_perc 10 \
                --seq_len $given_seq_len \
                --batch_size 32 \
                --num_epochs 1500 \
                --conditional_freezing \
                --feature_matching  \
#                 --use_sgd \
#                 --label_smoothing \
           
                

end = time.time()
elapsed_time = np.round((end - start)/60.0, 2)
print(f"All done in {elapsed_time} minutes!") 

print(data_name, p)
# Out:
# ...
# Running data: stocks, perc: 2
# Namespace(batch_size=32, conditional_freezing=True, d_lrn_rate=0.1, d_pretraining_epochs=20, dataset='stocks', feature_matching=True, g_lrn_rate=0.001, g_pretraining_epochs=50, label_smoothing=False, load_d=False, load_g=False, no_pretraining=False, no_save_d=False, no_save_g=False, num_epochs=1500, seq_len=24, training_thresh=2, use_sgd=False, valid_perc=10)
# No GPU available, training on CPU.
# ################################################################################
# Changing seq_len to  4
# [2021-09-14 05:48:58.469 pytorch-1-6-cpu-py36--ml-t3-medium-016478e629f45c0d047785aeb907:219 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2021-09-14 05:48:58.700 pytorch-1-6-cpu-py36--ml-t3-medium-016478e629f45c0d047785aeb907:219 INFO profiler_config_parser.py:102] Unable to find config at /opt/ml/input/config/profilerconfig.json. Profiler is disabled.
# --------------------------------------------------------------------------------
# ...
